# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\Shrey\Desktop\codes_proj\customer_journey_analyzer\venv\Scripts\python.exe
# 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]

# %%
# Cell 1
import sys; sys.path.append("..")
from src.data_generator import generate_sessions

df = generate_sessions(n_sessions=15000)
df.to_csv("../data/raw/sessions.csv", index=False)

print(f"Dataset shape: {df.shape}")
display(df.head())
display(df.dtypes)
display(df["converted"].value_counts(normalize=True).round(3))
# Out:
# Dataset shape: (15000, 17)
#    session_id        date    month   device  load_time_s  hour  is_weekend  \
# 0           0  2024-05-18  2024-05  desktop         3.23    15           1
# 1           1  2024-03-19  2024-03   mobile         2.21    16           0
# 2           2  2024-06-07  2024-06   mobile         5.30     8           0
# 3           3  2024-01-11  2024-01   tablet         1.19     1           0
# 4           4  2024-03-13  2024-03   mobile         2.52    23           0
#
#    is_new_user price_range  n_pages_viewed  has_coupon  cart_value utm_source  \
# 0            1      budget               6           1      606.76    organic
# 1            0         mid              12           1      819.04      email
# 2            0         mid               4           1     1687.01       paid
# 3            1     premium              15           0      259.98     social
# 4            1     premium              18           1       94.39       paid
#
# ...
